# %% [markdown]
# # Inter-Annotator Agreement

# %%
import pandas as pd
from collections import Counter
import numpy as np
from nltk import agreement
from os import walk

# %%
def create_reduced_df(df):
    result = []
    for index, row in df.iterrows():
        WorkerId = row.WorkerId
        for i in range(1,41):
            text = row['Input.text' + str(i)]
            _id = row['Input.id' + str(i)]
            answer = row['Answer.classification' + str(i)]
            batch_id = row['Input.batch_id']
            result.append({'workerId': WorkerId, 'movie_id':_id, 'batch_id': batch_id, 'text': text, 'answer':answer, 'number' : i})
    df_result = pd.DataFrame(result)
    df_result['answer'].replace({'hatespeech': 2, 'normal': 0, 'offensive': 1}, inplace=True)
    return df_result

# %%
path = 'data/movies_raw'
_, _, movie_names = next(walk(path))

# %%
def load_all_movies(path, movie_names):
    
    df_list = []
    
    for movie in movie_names:
        df = pd.read_csv(path + '/' + movie)
        df = create_reduced_df(df)
        df['movie'] = movie.split('.')[0]
        df_list.append(df)
        
    result_df = pd.concat(df_list)
    result_df = result_df.dropna()
    
    return result_df

# %%
df = load_all_movies(path, movie_names)

# %%
df.head(1)
# Out:
#         workerId                  movie_id    batch_id    text  answer  \
# 0  AVNP1F3CADQRW  AmericanHistoryX(1998)_1  1566624979  Derek.       0
#
#    number              movie
# 0       1  AmerricanHistoryX

# %%
len(df.workerId.unique())
# Out:
# 13

# %%
movie_id_test = []
def get_annotated_movie(df):
    
    result = []
    
    batch_ids = df.batch_id.unique()
    for batch_id in batch_ids:
        movie_ids = df[(df.batch_id==batch_id)].movie_id.unique()
        for movie_id in movie_ids:
            annotation_single = df[(df.batch_id==batch_id) & (df.movie_id==movie_id)]
            
            if len(annotation_single)>0:
                movie_name = annotation_single.movie.values[0]
                majority_answer = Counter(annotation_single.answer.values)
                majority_answer_single = majority_answer.most_common()[0][0]
                
                text = annotation_single.text.values[0]
                
                if majority_answer.most_common()[0][1] == 1:
                    
#                     print('even')
#                     print(majority_answer)
#                     print(result)
                    majority_answer_single = 1
                    movie_id_test.append(movie_id)
                result_single = {'movie_id': movie_id, 'batch_id': batch_id, 'majority_answer': majority_answer_single, 'text': text, 'movie_name': movie_name}
                result.append(result_single)
            else:
                print('last batch')
    result_df = pd.DataFrame(result)
    return result_df
#             result_single = [list(x) for x in annotation_single[['workerId', 'movie_id', 'answer']].values]
#             if len(result_single) > 0:
#                 result.append()

# %%
result_df_movies_final = get_annotated_movie(df)

# %%
result_df_movies_final.to_csv('all_movies.csv')

# %%
result_df_movies_final
# Out:
#                                       movie_id    batch_id  majority_answer  \
# 0                     AmericanHistoryX(1998)_1  1566624979                0
# 1                     AmericanHistoryX(1998)_2  1566624979                1
# 2                     AmericanHistoryX(1998)_3  1566624979                0
# 3                     AmericanHistoryX(1998)_4  1566624979                0
# 4                     AmericanHistoryX(1998)_5  1566624979                0
# ...                                        ...         ...              ...
# 10683       TheWolfofWallStreet2013BluRay_3724  3859903933                0
# 10684       TheWolfofWallStreet2013BluRay_3725  3859903933                0
# 10685  TheWolfofWallStreet2013BluRay_3726_3727  3859903933                0
# 10686       TheWolfofWallStreet2013BluRay_3728  3859903933                0
# 10687  TheWolfofWallStreet2013BluRay_3729_3730  3859903933                0
#
#                                                     text           movie_name
# 0                                                 Derek.    AmerricanHistoryX
# 1                        What the fuck are you thinking?    AmerricanHistoryX
# 2      There's a black guy outside breaking into your...    AmerricanHistoryX
# 3                            How long has he been there?    AmerricanHistoryX
# 4                                          I don't know.    AmerricanHistoryX
# ...                                                  ...                  ...
# 10683                                  Sell me this pen.  TheWolfofWallStreet
# 10684                             Well, it's a nice pen.  TheWolfofWallStreet
# 10685  You can use the pen to write down thoughts fro...  TheWolfofWallStreet
# 10686                                  Sell me this pen.  TheWolfofWallStreet
# 10687  Well... This pen works and I personally love t...  TheWolfofWallStreet
#
# [10688 rows x 5 columns]

# %%
def save_all_movies_for_training(result_df_movies_final):
    for name in result_df_movies_final.movie_name.unique():
        single_df = result_df_movies_final[result_df_movies_final.movie_name==name]
        single_df.to_csv(name + '_for_training' +  '.csv')

# %%
a = result_df_movies_final.majority_answer.value_counts().to_frame()
a['percentage'] = a['majority_answer'] / a.majority_answer.sum()

# %%
a.reset_index().rename(columns={'index': 'label'})
# Out:
#    label  majority_answer  percentage
# 0      0             9014    0.843376
# 1      1             1380    0.129117
# 2      2              294    0.027507

# %%
result_df_movies_final.groupby('movie_name').majority_answer.value_counts()
# Out:
# movie_name           majority_answer
# AmerricanHistoryX    0                  1304
#                      1                   207
#                      2                    54
# BlacKkKlansman       0                  1462
#                      1                    97
#                      2                    86
# Django_Unchained     0                  1551
#                      2                   117
#                      1                    79
# Pulp_Fiction         0                  1333
#                      1                   265
#                      2                    24
# South_Park           0                   890
#                      1                   145
#                      2                    11
# TheWolfofWallStreet  0                  2474
#                      1                   587
#                      2                     2
# Name: majority_answer, dtype: int64

# %%
result_df_movies_final[(result_df_movies_final['movie_name']=='TheWolfofWallStreet') & (result_df_movies_final['majority_answer']==1)]
# Out:
#                                               movie_id    batch_id  \
# 7631   TheWolfofWallStreet2013BluRay_7_8_9_10_11_12_13  3859903857
# 7643               TheWolfofWallStreet2013BluRay_33_34  3859903857
# 7644                  TheWolfofWallStreet2013BluRay_35  3859903857
# 7648                  TheWolfofWallStreet2013BluRay_42  3859903857
# 7672                  TheWolfofWallStreet2013BluRay_77  3859903858
# ...                                                ...         ...
# 10657               TheWolfofWallStreet2013BluRay_3682  3859903932
# 10660     TheWolfofWallStreet2013BluRay_3686_3687_3688  3859903932
# 10674               TheWolfofWallStreet2013BluRay_3709  3859903933
# 10676               TheWolfofWallStreet2013BluRay_3711  3859903933
# 10677     TheWolfofWallStreet2013BluRay_3712_3713_3714  3859903933
#
#        majority_answer                                               text  \
# 7631                 1  Stability. Integrity. Pride. One! Two! Three! ...
# 7643                 1  Yeah. She was the one with my cock in her mout...
# 7644                 1               So put your dick back in your pants.
# 7648                 1       I fuck hookers maybe five, six times a week.
# 7672                 1   You can save the fucking spotted owl with money.
# ...                ...                                                ...
# 10657                1                               It's fucking Chanel!
# 10660                1  Like my pops, Mad Max, had said, "The chickens...
# 10674                1  So listen. I've met some bad motherfuckers in ...
# 10676                1      I'm telling you, some real bad motherfuckers.
# 10677                1  But this guy, my good friend, Mr. Jordan Belfo...
#
#                 movie_name
# 7631   TheWolfofWallStreet
# 7643   TheWolfofWallStreet
# 7644   TheWolfofWallStreet
# 7648   TheWolfofWallStreet
# 7672   TheWolfofWallStreet
# ...                    ...
# 10657  TheWolfofWallStreet
# 10660  TheWolfofWallStreet
# 10674  TheWolfofWallStreet
# 10676  TheWolfofWallStreet
# 10677  TheWolfofWallStreet
#
# [587 rows x 5 columns]

# %%
result_df_movies_final.groupby('majority_answer').majority_answer.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='majority_answer,majority_answer'>

# %% [markdown]
# result_df_movies_final.to_csv('AmericanHistoryX_majority_annotated.csv')

# %% [markdown]
# ## calculate ties

# %%
df_ties = df.drop_duplicates('movie_id')

# %%
df_ties.describe
# Out:
# <bound method NDFrame.describe of             workerId                                 movie_id    batch_id  \
# 0      AVNP1F3CADQRW                 AmericanHistoryX(1998)_1  1566624979
# 1      AVNP1F3CADQRW                 AmericanHistoryX(1998)_2  1566624979
# 2      AVNP1F3CADQRW                 AmericanHistoryX(1998)_3  1566624979
# 3      AVNP1F3CADQRW                 AmericanHistoryX(1998)_4  1566624979
# 4      AVNP1F3CADQRW                 AmericanHistoryX(1998)_5  1566624979
# ...              ...                                      ...         ...
# 9138  A2H1RXUC8XNNIW       TheWolfofWallStreet2013BluRay_3724  3859903933
# 9139  A2H1RXUC8XNNIW       TheWolfofWallStreet2013BluRay_3725  3859903933
# 9140  A2H1RXUC8XNNIW  TheWolfofWallStreet2013BluRay_3726_3727  3859903933
# 9141  A2H1RXUC8XNNIW       TheWolfofWallStreet2013BluRay_3728  3859903933
# 9142  A2H1RXUC8XNNIW  TheWolfofWallStreet2013BluRay_3729_3730  3859903933
#
#                                                    text  answer  number  \
# 0                                                Derek.       0       1
# 1                       What the fuck are you thinking?       1       2
# 2     There's a black guy outside breaking into your...       2       3
# 3                           How long has he been there?       0       4
# 4                                         I don't know.       0       5
# ...                                                 ...     ...     ...
# 9138                                  Sell me this pen.       0      19
# 9139                             Well, it's a nice pen.       0      20
# 9140  You can use the pen to write down thoughts fro...       0      21
# 9141                                  Sell me this pen.       0      22
# 9142  Well... This pen works and I personally love t...       0      23
#
#                     movie
# 0       AmerricanHistoryX
# 1       AmerricanHistoryX
# 2       AmerricanHistoryX
# 3       AmerricanHistoryX
# 4       AmerricanHistoryX
# ...                   ...
# 9138  TheWolfofWallStreet
# 9139  TheWolfofWallStreet
# 9140  TheWolfofWallStreet
# 9141  TheWolfofWallStreet
# 9142  TheWolfofWallStreet
#
# [10688 rows x 7 columns]>

# %% [markdown]
# ### calculate ties.percentage

# %%
df_ties.shape[0]
# Out:
# 10688

# %%
len(movie_id_test)
# Out:
# 80

# %%
len(movie_id_test) / df_ties.shape[0]
# Out:
# 0.0074850299401197605

# %%
result_df_movies_final[(result_df_movies_final.batch_id==1566625003)][['text', 'majority_answer']]
# Out:
#                                                   text  majority_answer
# 280                               Gun! He's got a gun!                0
# 281                                     Shit! Back up!                1
# 282                          You make me fucking sick!                1
# 283                          Put down the fucking gun!                1
# 284                                  Shoot the nigger!                2
# 285                 Shoot him! Do it, Seth! Shoot him!                0
# 286                       Traitor! Do it, Seth! Do it!                0
# 287                                     Back up! Move!                0
# 288                         Back up! Back the fuck up!                1
# 289                                        Move! Move!                0
# 290                                  Easy, Derek! Hey!                0
# 291                                       Easy, Danny!                0
# 292                          Who do you think you are?                0
# 293        - Danny, relax. - Who do you think you are?                0
# 294                                 Take it easy, Dan.                0
# 295                           I fucking hate you, Der!                1
# 296                              All right. I mean it.                0
# 297               Huh? Come on. Shut up. Take it easy.                0
# 298                       What's happened to you, Der?                0
# 299                                      Take it easy.                0
# 300                       What's happened to you, Der?                0
# 301                                  Come on. Come on.                0
# 302                               It's just so fucked.                1
# 303       I'm sorry. You weren't supposed to see that.                0
# 304                            I told you not to come.                0
# 305                                     Fuck you, man.                1
# 306                             That was so fucked up.                1
# 307                                    I know, I know.                0
# 308        God, it wasn't supposed to happen that way.                0
# 309     That was fucked up. That's all there is to it.                1
# 310  That's not what I planned. It just all went to...                0
# 311             Just shit. Got totally out of control.                1
# 312                     What's fucking happening here?                1
# 313                                   Hey, look at me.                0
# 314                      I can't go back to that, Dan.                0
# 315                             Can't go back to what?                0
# 316                                      To any of it.                0
# 317  Those guys, the gang, that life. I'm done with...                0
# 318                     What happened to you up there?                0
# 319                       Feed line. Back up for chow.                0

# %%
df_ties[df_ties.movie_id.isin(movie_id_test)]
# Out:
#             workerId                            movie_id    batch_id  \
# 368   A182N7RLXGSCZG      AmericanHistoryX(1998)_382_383  1566624988
# 498    AVNP1F3CADQRW          AmericanHistoryX(1998)_182  1566624983
# 871    A4D99Y82KOLC8         AmericanHistoryX(1998)_1029  1566625003
# 1209   A4D99Y82KOLC8         AmericanHistoryX(1998)_1088  1566625005
# 2299  A182N7RLXGSCZG          AmericanHistoryX(1998)_351  1566624987
# ...              ...                                 ...         ...
# 1830   AVNP1F3CADQRW   TheWolfofWallStreet2013BluRay_772  3859903872
# 3618  A182N7RLXGSCZG  TheWolfofWallStreet2013BluRay_1472  3859903887
# 3620  A182N7RLXGSCZG  TheWolfofWallStreet2013BluRay_1474  3859903887
# 8064  A182N7RLXGSCZG  TheWolfofWallStreet2013BluRay_3293  3859903924
# 8315   AVNP1F3CADQRW  TheWolfofWallStreet2013BluRay_3398  3859903926
#
#                                                    text  answer  number  \
# 368   Good. I hate Tabitha Soren and her Zionist MTV...       1       9
# 498   Minorities don't give two shits about this cou...       1      19
# 871              Just shit. Got totally out of control.       2      32
# 1209               Bad-ass peckerwood with an attitude.       0      10
# 2299  When was the last time you were actually able ...       1      20
# ...                                                 ...     ...     ...
# 1830  You're a bunch of fucking sleazy salesmen, right?       2      31
# 3618             You think this is 'cause you're a fag?       1      19
# 3620  And I go on vacation with him and his boyfrien...       1      21
# 8064                      I'm Swiss, I'm not communist.       1      25
# 8315                    So boring. I wanna kill myself.       2      36
#
#                     movie
# 368     AmerricanHistoryX
# 498     AmerricanHistoryX
# 871     AmerricanHistoryX
# 1209    AmerricanHistoryX
# 2299    AmerricanHistoryX
# ...                   ...
# 1830  TheWolfofWallStreet
# 3618  TheWolfofWallStreet
# 3620  TheWolfofWallStreet
# 8064  TheWolfofWallStreet
# 8315  TheWolfofWallStreet
#
# [80 rows x 7 columns]

# %%
df_ties[df_ties.movie_id.isin(movie_id_test)].groupby('workerId').answer.value_counts()
# Out:
# workerId        answer
# A13WYZ8AXD6ODX  2          5
#                 1          3
#                 0          2
# A182N7RLXGSCZG  2         18
#                 1          6
#                 0          2
# A1L1S0IAPZB4MO  2          4
# A2H1RXUC8XNNIW  0         10
#                 1          6
#                 2          2
# A2MAGMY4JMDD3V  1          1
# A4D99Y82KOLC8   0          5
#                 1          1
#                 2          1
# AVNP1F3CADQRW   1          9
#                 2          5
# Name: answer, dtype: int64

# %% [raw]
# df_recuced.groupby('batch_id')

# %% [raw]
# a = df_recuced.workerId.unique()

# %% [raw]
# b = ['A1R6J2VHRK5YR6', 'A182N7RLXGSCZG', 'A2MAGMY4JMDD3V', 'A2V2ETRC6AO6GF',
#              'A2NHFSO7GMM8QR', 'A2AA0GM76ENV5C', 'A3E74I2YTGJCRF', 'AVNP1F3CADQRW',
#              'A13WYZ8AXD6ODX',  'A141B3S3ZLY8DI',  'A2H1RXUC8XNNIW',  'A47P5PR27PW3B',  'APZPQ332QVEUY',
#              'A141B3S3ZLY8DI', 'A1ZDMOQ8PWL60C', 'A2H1RXUC8XNNIW', 'A32D8TKZV2RQ4Y', 'A3PDQ3DJGJA78Y']

# %% [raw]
# c = set(a) - set(b)

# %% [raw]
# c

# %%
def get_percentage(answer, df):
    
    classifications = df[(df.answer==answer)].groupby('workerId').answer.value_counts().to_frame(name='total_classifications').reset_index('workerId')
    total_batches = df[(df.answer==answer)].drop_duplicates(subset=['batch_id', 'workerId']).groupby('workerId').batch_id.count().to_frame('total_batches').reset_index('workerId')
    
    merged_df = classifications.merge(total_batches, on='workerId')
    
    merged_df['number_dialogues'] = merged_df['total_batches'] * 40
    
    merged_df['percentage_as_' + str(answer)] = (merged_df['total_classifications'] / merged_df['number_dialogues'])
    
    merged_df.sort_values(by='number_dialogues' , ascending=False, inplace=True)
    return merged_df

# %%
get_percentage(0, df)
# Out:
#           workerId  total_classifications  total_batches  number_dialogues  \
# 5   A2H1RXUC8XNNIW                   7116            213              8520
# 1   A182N7RLXGSCZG                   6451            198              7920
# 11   A4D99Y82KOLC8                   4743            138              5520
# 12   AVNP1F3CADQRW                   3570            113              4520
# 0   A13WYZ8AXD6ODX                   1380             40              1600
# 6   A2MAGMY4JMDD3V                   1272             39              1560
# 10  A3E74I2YTGJCRF                    634             22               880
# 2   A1L1S0IAPZB4MO                    128             16               640
# 9   A32D8TKZV2RQ4Y                    442             12               480
# 8   A2V2ETRC6AO6GF                    353             10               400
# 7   A2NHFSO7GMM8QR                    204              6               240
# 4   A2AA0GM76ENV5C                    120              4               160
# 3   A1ZDMOQ8PWL60C                     65              2                80
#
#     percentage_as_0
# 5          0.835211
# 1          0.814520
# 11         0.859239
# 12         0.789823
# 0          0.862500
# 6          0.815385
# 10         0.720455
# 2          0.200000
# 9          0.920833
# 8          0.882500
# 7          0.850000
# 4          0.750000
# 3          0.812500

# %%
get_percentage(1, df)
# Out:
#           workerId  total_classifications  total_batches  number_dialogues  \
# 5   A2H1RXUC8XNNIW                   1100            192              7680
# 1   A182N7RLXGSCZG                   1071            181              7240
# 11   A4D99Y82KOLC8                    532            118              4720
# 12   AVNP1F3CADQRW                    726            109              4360
# 6   A2MAGMY4JMDD3V                    228             38              1520
# 0   A13WYZ8AXD6ODX                    112             36              1440
# 10  A3E74I2YTGJCRF                    206             22               880
# 2   A1L1S0IAPZB4MO                    367             15               600
# 9   A32D8TKZV2RQ4Y                     37             11               440
# 8   A2V2ETRC6AO6GF                     38              8               320
# 7   A2NHFSO7GMM8QR                     35              6               240
# 4   A2AA0GM76ENV5C                     25              4               160
# 3   A1ZDMOQ8PWL60C                     11              2                80
#
#     percentage_as_1
# 5          0.143229
# 1          0.147928
# 11         0.112712
# 12         0.166514
# 6          0.150000
# 0          0.077778
# 10         0.234091
# 2          0.611667
# 9          0.084091
# 8          0.118750
# 7          0.145833
# 4          0.156250
# 3          0.137500

# %%
get_percentage(2, df)
# Out:
#           workerId  total_classifications  total_batches  number_dialogues  \
# 1   A182N7RLXGSCZG                    259             85              3400
# 5   A2H1RXUC8XNNIW                    187             77              3080
# 12   AVNP1F3CADQRW                    194             77              3080
# 11   A4D99Y82KOLC8                    145             59              2360
# 0   A13WYZ8AXD6ODX                    108             25              1000
# 6   A2MAGMY4JMDD3V                     60             19               760
# 2   A1L1S0IAPZB4MO                    110             15               600
# 8   A2V2ETRC6AO6GF                      9              6               240
# 4   A2AA0GM76ENV5C                     15              3               120
# 10  A3E74I2YTGJCRF                      5              3               120
# 3   A1ZDMOQ8PWL60C                      4              1                40
# 7   A2NHFSO7GMM8QR                      1              1                40
# 9   A32D8TKZV2RQ4Y                      1              1                40
#
#     percentage_as_2
# 1          0.076176
# 5          0.060714
# 12         0.062987
# 11         0.061441
# 0          0.108000
# 6          0.078947
# 2          0.183333
# 8          0.037500
# 4          0.125000
# 10         0.041667
# 3          0.100000
# 7          0.025000
# 9          0.025000

# %%
def get_fleiss_kappa(df, n, k):
    result = []
    annotation_all = []
    result_check = []
    df['answer'].replace({'hatespeech': 2, 'normal': 0, 'offensive': 1}, inplace=True)
    batch_ids = df.batch_id.unique()
    for batch_id in batch_ids:
        movie_ids = df[(df.batch_id==batch_id)].movie_id.unique()
        worker_ids = df[(df.batch_id==batch_id)].workerId.unique()
        
        annotation_singles = []
        for movie_id in movie_ids:
            annotation_single = df[(df.batch_id==batch_id) & (df.movie_id==movie_id)]
            f_k_single = [list(x) for x in annotation_single[['workerId', 'movie_id', 'answer']].values]
#             print(f_k_single)
#             break
            
            annotation_all.extend(f_k_single)
            annotation_singles.extend(f_k_single)
            result_check.append({'batch_id': str(batch_id), 'movie_id': movie_id, 'answer_1': f_k_single[0][2], 'answer_2': f_k_single[1][2],  'answer_3': f_k_single[2][2], 'worker_1': f_k_single[0][0], 'worker_2': f_k_single[1][0], 'worker_3': f_k_single[2][0]})
        # print(annotation_singles)
        ratingtask = agreement.AnnotationTask(annotation_singles)
        try:
            f_k= ratingtask.multi_kappa()
        except:
            f_k = 1
        result.append({'fleiss_kappa': f_k, 'batch_id': batch_id, 'worker_1': worker_ids[0], 'worker_2': worker_ids[1], 'worker_3': worker_ids[2]})
    result_df = pd.DataFrame(result)
    result_check_df = pd.DataFrame(result_check)
    return result_df, result_check_df, annotation_all

# %%
result_df, result_check_df, annotation_all = get_fleiss_kappa(df, n=3, k=3)

# %%
result_df
# Out:
#      fleiss_kappa    batch_id        worker_1        worker_2        worker_3
# 0        0.350649  1566624979   AVNP1F3CADQRW   A4D99Y82KOLC8  A182N7RLXGSCZG
# 1        0.485767  1566625000   AVNP1F3CADQRW   A4D99Y82KOLC8  A182N7RLXGSCZG
# 2        0.929577  1566625009  A2V2ETRC6AO6GF  A182N7RLXGSCZG   AVNP1F3CADQRW
# 3        0.468385  1566624988  A182N7RLXGSCZG   A4D99Y82KOLC8   AVNP1F3CADQRW
# 4        0.343750  1566624983   AVNP1F3CADQRW   A4D99Y82KOLC8  A182N7RLXGSCZG
# ..            ...         ...             ...             ...             ...
# 266      0.916405  3859903929  A2MAGMY4JMDD3V  A182N7RLXGSCZG  A2H1RXUC8XNNIW
# 267      0.962512  3859903930  A182N7RLXGSCZG  A3E74I2YTGJCRF  A2H1RXUC8XNNIW
# 268      0.900000  3859903931  A2H1RXUC8XNNIW  A3E74I2YTGJCRF  A182N7RLXGSCZG
# 269      0.646465  3859903932  A182N7RLXGSCZG  A2H1RXUC8XNNIW   AVNP1F3CADQRW
# 270      1.000000  3859903933  A2H1RXUC8XNNIW   AVNP1F3CADQRW  A182N7RLXGSCZG
#
# [271 rows x 5 columns]

# %%
result_df.fleiss_kappa.mean()
# Out:
# 0.509893361378852

# %%
annotation_triples = [('A182N7RLXGSCZG', 'AmericanHistoryX(1998)_1405', 1), 
                       ('AVNP1F3CADQRW', 'AmericanHistoryX(1998)_1405', 1), 
                       ('A4D99Y82KOLC8', 'AmericanHistoryX(1998)_1405', 1)]

task = agreement.AnnotationTask(annotation_triples)

# %% [raw]
# task.multi_kappa()

# %%
from sklearn.metrics import cohen_kappa_score
labeler1 = [1, 1, 0, 2]
labeler2 = [1, 1, 1, 1]
cohen_kappa_score(labeler1, labeler2)
# Out:
# 0.0

# %% [raw]
# from nltk import agreement
# rater1 = [1,1,1]
# rater2 = [1,1,1]
# rater3 = [0,1,1]
#
# taskdata=[[0,str(i),str(rater1[i])] for i in range(0,len(rater1))]+[[1,str(i),str(rater2[i])] for i in range(0,len(rater2))]+[[2,str(i),str(rater3[i])] for i in range(0,len(rater3))]
# ratingtask = agreement.AnnotationTask(data=taskdata)
# print("kappa " +str(ratingtask.kappa()))
# print("fleiss " + str(ratingtask.multi_kappa()))
# print("alpha " +str(ratingtask.alpha()))
# print("scotts " + str(ratingtask.pi()))

# %%
result_check_df.head()
# Out:
#      batch_id                  movie_id  answer_1  answer_2  answer_3  \
# 0  1566624979  AmericanHistoryX(1998)_1         0         0         0
# 1  1566624979  AmericanHistoryX(1998)_2         1         1         1
# 2  1566624979  AmericanHistoryX(1998)_3         2         0         0
# 3  1566624979  AmericanHistoryX(1998)_4         0         0         0
# 4  1566624979  AmericanHistoryX(1998)_5         0         0         0
#
#         worker_1       worker_2        worker_3
# 0  AVNP1F3CADQRW  A4D99Y82KOLC8  A182N7RLXGSCZG
# 1  AVNP1F3CADQRW  A4D99Y82KOLC8  A182N7RLXGSCZG
# 2  AVNP1F3CADQRW  A4D99Y82KOLC8  A182N7RLXGSCZG
# 3  AVNP1F3CADQRW  A4D99Y82KOLC8  A182N7RLXGSCZG
# 4  AVNP1F3CADQRW  A4D99Y82KOLC8  A182N7RLXGSCZG

# %%
result_check_df.agreement.value_counts(normalize=True)
# Out:
# 1.000000    0.812874
# 0.666667    0.120977
# 0.333333    0.066149
# Name: agreement, dtype: float64

# %%
disagreement_movoie_id = []
def fx(x):
    row = result_check_df[result_check_df.movie_id==x]
    answer_1 = row.answer_1.values[0]
    answer_2 = row.answer_2.values[0]
    answer_3 = row.answer_3.values[0]
    movie_id = row.movie_id.values[0]
    
    
    a = [answer_1, answer_2, answer_3]
    b = {}
    for i in a:
        b[i] = b.get(i, 0) + 1
    sorted_dict = dict(sorted(b.items()))
    number = list(sorted_dict.values())[0]
    
    if number == 3:
        result = 1  
    elif len(sorted_dict) == 3:
        result = 1/3
        disagreement_movoie_id.append(movie_id)
    else:
        result = 2/3
    return result

result_check_df['agreement'] = result_check_df.movie_id.apply(fx)

# %%
agreement_result = result_check_df.agreement.value_counts().to_frame()
agreement_result['percentage'] = agreement_result['agreement'] / agreement_result.agreement.sum()

# %%
agreement_result.reset_index().rename(columns={'index': 'percentage_they_do_agree'})
# Out:
#    percentage_they_do_agree  agreement  percentage
# 0                  1.000000       8688    0.812874
# 1                  0.666667       1920    0.179641
# 2                  0.333333         80    0.007485

# %%
result_check_df[result_check_df.movie_id.isin(disagreement_movoie_id)]
# Out:
#          batch_id                            movie_id  answer_1  answer_2  \
# 128    1566624988      AmericanHistoryX(1998)_382_383         2         1
# 178    1566624983          AmericanHistoryX(1998)_182         2         1
# 311    1566625003         AmericanHistoryX(1998)_1029         3         2
# 409    1566625005         AmericanHistoryX(1998)_1088         1         3
# 779    1566624987          AmericanHistoryX(1998)_351         2         1
# ...           ...                                 ...       ...       ...
# 8255   3859903872   TheWolfofWallStreet2013BluRay_772         3         1
# 8843   3859903887  TheWolfofWallStreet2013BluRay_1472         2         1
# 8845   3859903887  TheWolfofWallStreet2013BluRay_1474         2         1
# 10329  3859903924  TheWolfofWallStreet2013BluRay_3293         2         1
# 10420  3859903926  TheWolfofWallStreet2013BluRay_3398         3         1
#
#        answer_3        worker_1        worker_2        worker_3  agreement
# 128           3  A182N7RLXGSCZG   A4D99Y82KOLC8   AVNP1F3CADQRW   0.333333
# 178           3   AVNP1F3CADQRW   A4D99Y82KOLC8  A182N7RLXGSCZG   0.333333
# 311           1   A4D99Y82KOLC8   AVNP1F3CADQRW  A182N7RLXGSCZG   0.333333
# 409           2   A4D99Y82KOLC8   AVNP1F3CADQRW  A182N7RLXGSCZG   0.333333
# 779           3  A182N7RLXGSCZG   AVNP1F3CADQRW   A4D99Y82KOLC8   0.333333
# ...         ...             ...             ...             ...        ...
# 8255          2   AVNP1F3CADQRW  A182N7RLXGSCZG  A2H1RXUC8XNNIW   0.333333
# 8843          3  A182N7RLXGSCZG  A32D8TKZV2RQ4Y  A2H1RXUC8XNNIW   0.333333
# 8845          3  A182N7RLXGSCZG  A32D8TKZV2RQ4Y  A2H1RXUC8XNNIW   0.333333
# 10329         3  A182N7RLXGSCZG  A2H1RXUC8XNNIW  A3E74I2YTGJCRF   0.333333
# 10420         2   AVNP1F3CADQRW  A2H1RXUC8XNNIW  A182N7RLXGSCZG   0.333333
#
# [80 rows x 9 columns]

# %%
def get_charts(df):
    df['answer_1'].replace({0: 1, 1: 2, 2: 3}, inplace=True)
    df['answer_2'].replace({0: 1, 1: 2, 2: 3}, inplace=True)
    df['answer_3'].replace({0: 1, 1: 2, 2: 3}, inplace=True)
    for batch_id in df.batch_id.unique():
        w_1, w_2, w_3 = df[df.batch_id==batch_id][['worker_1', 'worker_2', 'worker_3']].values[0] 
        title = 'batch_id: ' + str(batch_id) + '_' + 'w_1: ' + w_1 + '_' +  'w_2: ' + w_2 + '_' +  'w_3: ' + w_3
        df[df.batch_id==batch_id].plot(kind='bar', stacked=True, title=title)

# %%
get_charts(result_check_df)
# Out:
# C:\Users\Niklas\AppData\Roaming\Python\Python37\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
